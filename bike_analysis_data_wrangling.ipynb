# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import copy
import math

# %%
df_daily = pd.read_csv('data/day.csv')
df_hourly = pd.read_csv('data/hour.csv')

# %%
df_daily.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df_daily.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# 730  2729

# %% [markdown]
# Appears to be data for every day from 2011-01-01 to 2012-12-31 <br>
#
# 2012 was a leap year, which is why it had 366 days. <br>
#
# We have correct total number of days (365 + 366 = 731)

# %% [markdown]
# "season": (1:winter, 2:spring, 3:summer, 4:fall) <br>
# "yr" : year (0: 2011, 1:2012)<br>
# "mnth" : month ( 1 to 12)<br>
# "holiday": public holiday (1) or not (0) <br>
# "weekday": sunday = 0, monday = 1, etc <br>
# "workingday": 1: yes, 0: weekend or holiday <br>
# "weathersit" : 1: good, 4: terrible <br>
# - 1: Clear, Few clouds, Partly cloudy, Partly cloudy <br>
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist <br>
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds <br>
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog <br>
#
# "temp":  Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale) <br>
# (so t = temp * (t_max - t_min) + t_min)
#
# "atemp": Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale) <br>
#
# "hum": Normalized humidity. The values are divided to 100 (max) <br>
#
# "windspeed": Normalized wind speed. The values are divided to 67 (max) <br>
#
# "casual": count of casual users <br>
#
# "registered": count of registered users <br>
#
# "cnt": "casual" + "registered"

# %%
df_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
# Drop redundant column in daily data
df_daily.drop('instant', axis = 1, inplace = True)

# %%
df_daily.head()
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1        0        6           0           2
# 1  2011-01-02       1   0     1        0        0           0           2
# 2  2011-01-03       1   0     1        0        1           1           1
# 3  2011-01-04       1   0     1        0        2           1           1
# 4  2011-01-05       1   0     1        0        3           1           1
#
#        temp     atemp       hum  windspeed  casual  registered   cnt
# 0  0.344167  0.363625  0.805833   0.160446     331         654   985
# 1  0.363478  0.353739  0.696087   0.248539     131         670   801
# 2  0.196364  0.189405  0.437273   0.248309     120        1229  1349
# 3  0.200000  0.212122  0.590435   0.160296     108        1454  1562
# 4  0.226957  0.229270  0.436957   0.186900      82        1518  1600

# %%
# Rename column labels in df_day to make them more readable

columns = {'dteday':'date',
            'yr': 'year',
            'mnth': 'month',
            'weekday':'day_of_week',
            'workingday': 'work_day',
            'weathersit': 'weather_sit',
            'atemp': 'app_temp',
            'hum': 'humidity',
            'windspeed': 'wind_speed',
            'cnt': 'total'
            }

df_daily.rename(columns = columns, inplace = True)

# %%
df_daily.head()
# Out:
#          date  season  year  month  holiday  day_of_week  work_day  \
# 0  2011-01-01       1     0      1        0            6         0
# 1  2011-01-02       1     0      1        0            0         0
# 2  2011-01-03       1     0      1        0            1         1
# 3  2011-01-04       1     0      1        0            2         1
# 4  2011-01-05       1     0      1        0            3         1
#
#    weather_sit      temp  app_temp  humidity  wind_speed  casual  registered  \
# 0            2  0.344167  0.363625  0.805833    0.160446     331         654
# 1            2  0.363478  0.353739  0.696087    0.248539     131         670
# 2            1  0.196364  0.189405  0.437273    0.248309     120        1229
# 3            1  0.200000  0.212122  0.590435    0.160296     108        1454
# 4            1  0.226957  0.229270  0.436957    0.186900      82        1518
#
#    total
# 0    985
# 1    801
# 2   1349
# 3   1562
# 4   1600

# %%
df_daily.shape
# Out:
# (731, 15)

# %%
df_daily.isna().sum()
# Out:
# date           0
# season         0
# year           0
# month          0
# holiday        0
# day_of_week    0
# work_day       0
# weather_sit    0
# temp           0
# app_temp       0
# humidity       0
# wind_speed     0
# casual         0
# registered     0
# total          0
# dtype: int64

# %%
df_daily.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great. No missing values and no duplicates.

# %%
# Drop redundant column in hourly data
df_hourly.drop('instant', axis = 1, inplace = True)

# %%
df_hourly.head(20)
# Out:
#         dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0   2011-01-01       1   0     1   0        0        6           0
# 1   2011-01-01       1   0     1   1        0        6           0
# 2   2011-01-01       1   0     1   2        0        6           0
# 3   2011-01-01       1   0     1   3        0        6           0
# 4   2011-01-01       1   0     1   4        0        6           0
# 5   2011-01-01       1   0     1   5        0        6           0
# 6   2011-01-01       1   0     1   6        0        6           0
# 7   2011-01-01       1   0     1   7        0        6           0
# 8   2011-01-01       1   0     1   8        0        6           0
# 9   2011-01-01       1   0     1   9        0        6           0
# 10  2011-01-01       1   0     1  10        0        6           0
# 11  2011-01-01       1   0     1  11        0        6           0
# 12  2011-01-01       1   0     1  12        0        6           0
# 13  2011-01-01       1   0     1  13        0        6           0
# 14  2011-01-01       1   0     1  14        0        6           0
# 15  2011-01-01       1   0     1  15        0        6           0
# 16  2011-01-01       1   0     1  16        0        6           0
# 17  2011-01-01       1   0     1  17        0        6           0
# 18  2011-01-01       1   0     1  18        0        6           0
# 19  2011-01-01       1   0     1  19        0        6           0
#
#     weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0            1  0.24  0.2879  0.81     0.0000       3          13   16
# 1            1  0.22  0.2727  0.80     0.0000       8          32   40
# 2            1  0.22  0.2727  0.80     0.0000       5          27   32
# 3            1  0.24  0.2879  0.75     0.0000       3          10   13
# 4            1  0.24  0.2879  0.75     0.0000       0           1    1
# 5            2  0.24  0.2576  0.75     0.0896       0           1    1
# 6            1  0.22  0.2727  0.80     0.0000       2           0    2
# 7            1  0.20  0.2576  0.86     0.0000       1           2    3
# 8            1  0.24  0.2879  0.75     0.0000       1           7    8
# 9            1  0.32  0.3485  0.76     0.0000       8           6   14
# 10           1  0.38  0.3939  0.76     0.2537      12          24   36
# 11           1  0.36  0.3333  0.81     0.2836      26          30   56
# 12           1  0.42  0.4242  0.77     0.2836      29          55   84
# 13           2  0.46  0.4545  0.72     0.2985      47          47   94
# 14           2  0.46  0.4545  0.72     0.2836      35          71  106
# 15           2  0.44  0.4394  0.77     0.2985      40          70  110
# 16           2  0.42  0.4242  0.82     0.2985      41          52   93
# 17           2  0.44  0.4394  0.82     0.2836      15          52   67
# 18           3  0.42  0.4242  0.88     0.2537       9          26   35
# 19           3  0.42  0.4242  0.88     0.2537       6          31   37

# %%
df_hourly.shape
# Out:
# (17379, 16)

# %%
# Calculate how many rows are missing from df_hour
# For every row in df_day, there should be 24 rows in df_hour
(df_daily.shape[0] * 24) - (df_hourly.shape[0])
# Out:
# 165

# %% [markdown]
# We have 165 rows missing from df_hour

# %%
# Rename column labels in df_hourly to make them more readable

columns = {'dteday':'date',
            'yr': 'year',
            'mnth': 'month',
            'weekday':'day_of_week',
            'workingday': 'work_day',
            'weathersit': 'weather_sit',
            'atemp': 'app_temp',
            'hum': 'humidity',
            'windspeed': 'wind_speed',
            'cnt': 'total'
            }

df_hourly.rename(columns = columns, inplace = True)

# %%
df_hourly.head()
# Out:
#          date  season  year  month  hr  holiday  day_of_week  work_day  \
# 0  2011-01-01       1     0      1   0        0            6         0
# 1  2011-01-01       1     0      1   1        0            6         0
# 2  2011-01-01       1     0      1   2        0            6         0
# 3  2011-01-01       1     0      1   3        0            6         0
# 4  2011-01-01       1     0      1   4        0            6         0
#
#    weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 0            1  0.24    0.2879      0.81         0.0       3          13
# 1            1  0.22    0.2727      0.80         0.0       8          32
# 2            1  0.22    0.2727      0.80         0.0       5          27
# 3            1  0.24    0.2879      0.75         0.0       3          10
# 4            1  0.24    0.2879      0.75         0.0       0           1
#
#    total
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
df_hourly.rename(columns = {'hr':'hour'}, inplace = True)

# %%
df_hourly.head()
# Out:
#          date  season  year  month  hour  holiday  day_of_week  work_day  \
# 0  2011-01-01       1     0      1     0        0            6         0
# 1  2011-01-01       1     0      1     1        0            6         0
# 2  2011-01-01       1     0      1     2        0            6         0
# 3  2011-01-01       1     0      1     3        0            6         0
# 4  2011-01-01       1     0      1     4        0            6         0
#
#    weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 0            1  0.24    0.2879      0.81         0.0       3          13
# 1            1  0.22    0.2727      0.80         0.0       8          32
# 2            1  0.22    0.2727      0.80         0.0       5          27
# 3            1  0.24    0.2879      0.75         0.0       3          10
# 4            1  0.24    0.2879      0.75         0.0       0           1
#
#    total
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
df_hourly.head()
# Out:
#          date  season  year  month  hour  holiday  day_of_week  work_day  \
# 0  2011-01-01       1     0      1     0        0            6         0
# 1  2011-01-01       1     0      1     1        0            6         0
# 2  2011-01-01       1     0      1     2        0            6         0
# 3  2011-01-01       1     0      1     3        0            6         0
# 4  2011-01-01       1     0      1     4        0            6         0
#
#    weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 0            1  0.24    0.2879      0.81         0.0       3          13
# 1            1  0.22    0.2727      0.80         0.0       8          32
# 2            1  0.22    0.2727      0.80         0.0       5          27
# 3            1  0.24    0.2879      0.75         0.0       3          10
# 4            1  0.24    0.2879      0.75         0.0       0           1
#
#    total
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
df_hourly.isna().sum()
# Out:
# date           0
# season         0
# year           0
# month          0
# hour           0
# holiday        0
# day_of_week    0
# work_day       0
# weather_sit    0
# temp           0
# app_temp       0
# humidity       0
# wind_speed     0
# casual         0
# registered     0
# total          0
# dtype: int64

# %%
df_hourly.duplicated().sum()
# Out:
# 0

# %%
df_daily [df_daily['holiday'] == 1]
# Out:
#            date  season  year  month  holiday  day_of_week  work_day  \
# 16   2011-01-17       1     0      1        1            1         0
# 51   2011-02-21       1     0      2        1            1         0
# 104  2011-04-15       2     0      4        1            5         0
# 149  2011-05-30       2     0      5        1            1         0
# 184  2011-07-04       3     0      7        1            1         0
# 247  2011-09-05       3     0      9        1            1         0
# 282  2011-10-10       4     0     10        1            1         0
# 314  2011-11-11       4     0     11        1            5         0
# 327  2011-11-24       4     0     11        1            4         0
# 359  2011-12-26       1     0     12        1            1         0
# 366  2012-01-02       1     1      1        1            1         0
# 380  2012-01-16       1     1      1        1            1         0
# 415  2012-02-20       1     1      2        1            1         0
# 471  2012-04-16       2     1      4        1            1         0
# 513  2012-05-28       2     1      5        1            1         0
# 550  2012-07-04       3     1      7        1            3         0
# 611  2012-09-03       3     1      9        1            1         0
# 646  2012-10-08       4     1     10        1            1         0
# 681  2012-11-12       4     1     11        1            1         0
# 691  2012-11-22       4     1     11        1            4         0
# 724  2012-12-25       1     1     12        1            2         0
#
#      weather_sit      temp  app_temp  humidity  wind_speed  casual  \
# 16             2  0.175833  0.176771  0.537500    0.194017     117
# 51             2  0.303333  0.284075  0.605000    0.307846     195
# 104            1  0.446667  0.441913  0.671250    0.226375     642
# 149            1  0.733333  0.671092  0.685000    0.131225    1549
# 184            2  0.726667  0.665417  0.637917    0.081479    3065
# 247            2  0.673333  0.625646  0.790417    0.212696    1236
# 282            1  0.570833  0.542925  0.733750    0.042304    1514
# 314            1  0.324167  0.306817  0.446250    0.314675     440
# 327            1  0.373333  0.372471  0.549167    0.167304     560
# 359            1  0.321739  0.315535  0.506957    0.239465     430
# 366            1  0.273043  0.252304  0.381304    0.329665     244
# 380            1  0.190000  0.190663  0.522500    0.231358     217
# 415            1  0.280000  0.273391  0.507826    0.229083     502
# 471            1  0.664167  0.614925  0.561667    0.284829    1198
# 513            1  0.712500  0.679300  0.676250    0.196521    2557
# 550            1  0.789167  0.732337  0.538750    0.134950    2562
# 611            1  0.707500  0.661629  0.790833    0.151121    1965
# 646            2  0.383333  0.387608  0.709583    0.189679     874
# 681            1  0.485000  0.475383  0.741667    0.173517    1097
# 691            1  0.340000  0.350371  0.580417    0.052871     955
# 724            2  0.291304  0.294465  0.734783    0.168726     440
#
#      registered  total
# 16          883   1000
# 51          912   1107
# 104        2484   3126
# 149        2549   4098
# 184        2978   6043
# 247        2115   3351
# 282        3603   5117
# 314        2928   3368
# 327         935   1495
# 359         887   1317
# 366        1707   1951
# 380        2081   2298
# 415        2627   3129
# 471        5172   6370
# 513        3486   6043
# 550        4841   7403
# 611        4069   6034
# 646        4604   5478
# 681        5172   6269
# 691        1470   2425
# 724         573   1013

# %%
df_daily['holiday'] = df_daily['holiday'].apply(lambda x: 'no' if x == 0 else 'yes')
df_hourly['holiday'] = df_hourly['holiday'].apply(lambda x: 'no' if x == 0 else 'yes')

# %%
df_daily.head(20)
#df_hourly.head()
# Out:
#           date  season  year  month holiday  day_of_week  work_day  \
# 0   2011-01-01       1     0      1      no            6         0
# 1   2011-01-02       1     0      1      no            0         0
# 2   2011-01-03       1     0      1      no            1         1
# 3   2011-01-04       1     0      1      no            2         1
# 4   2011-01-05       1     0      1      no            3         1
# 5   2011-01-06       1     0      1      no            4         1
# 6   2011-01-07       1     0      1      no            5         1
# 7   2011-01-08       1     0      1      no            6         0
# 8   2011-01-09       1     0      1      no            0         0
# 9   2011-01-10       1     0      1      no            1         1
# 10  2011-01-11       1     0      1      no            2         1
# 11  2011-01-12       1     0      1      no            3         1
# 12  2011-01-13       1     0      1      no            4         1
# 13  2011-01-14       1     0      1      no            5         1
# 14  2011-01-15       1     0      1      no            6         0
# 15  2011-01-16       1     0      1      no            0         0
# 16  2011-01-17       1     0      1     yes            1         0
# 17  2011-01-18       1     0      1      no            2         1
# 18  2011-01-19       1     0      1      no            3         1
# 19  2011-01-20       1     0      1      no            4         1
#
#     weather_sit      temp  app_temp  humidity  wind_speed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833    0.160446     331         654
# 1             2  0.363478  0.353739  0.696087    0.248539     131         670
# 2             1  0.196364  0.189405  0.437273    0.248309     120        1229
# 3             1  0.200000  0.212122  0.590435    0.160296     108        1454
# 4             1  0.226957  0.229270  0.436957    0.186900      82        1518
# 5             1  0.204348  0.233209  0.518261    0.089565      88        1518
# 6             2  0.196522  0.208839  0.498696    0.168726     148        1362
# 7             2  0.165000  0.162254  0.535833    0.266804      68         891
# 8             1  0.138333  0.116175  0.434167    0.361950      54         768
# 9             1  0.150833  0.150888  0.482917    0.223267      41        1280
# 10            2  0.169091  0.191464  0.686364    0.122132      43        1220
# 11            1  0.172727  0.160473  0.599545    0.304627      25        1137
# 12            1  0.165000  0.150883  0.470417    0.301000      38        1368
# 13            1  0.160870  0.188413  0.537826    0.126548      54        1367
# 14            2  0.233333  0.248112  0.498750    0.157963     222        1026
# 15            1  0.231667  0.234217  0.483750    0.188433     251         953
# 16            2  0.175833  0.176771  0.537500    0.194017     117         883
# 17            2  0.216667  0.232333  0.861667    0.146775       9         674
# 18            2  0.292174  0.298422  0.741739    0.208317      78        1572
# 19            2  0.261667  0.255050  0.538333    0.195904      83        1844
#
#     total
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# 5    1606
# 6    1510
# 7     959
# 8     822
# 9    1321
# 10   1263
# 11   1162
# 12   1406
# 13   1421
# 14   1248
# 15   1204
# 16   1000
# 17    683
# 18   1650
# 19   1927

# %% [markdown]
# Now change day_of_week to 'mon', 'tue', etc.

# %%
# "weekday": 
# sunday = 0 
# monday = 1
# tuesday = 2
# etc

df_daily ['day_of_week'] = df_daily['day_of_week'].apply(lambda x: 'sun' if x == 0
                                                            else 'mon' if x == 1
                                                            else 'tue' if x == 2
                                                            else 'wed' if x == 3
                                                            else 'thu' if x == 4
                                                            else 'fri' if x == 5
                                                            else 'sat')

df_hourly ['day_of_week'] = df_hourly['day_of_week'].apply(lambda x: 'sun' if x == 0
                                                            else 'mon' if x == 1
                                                            else 'tue' if x == 2
                                                            else 'wed' if x == 3
                                                            else 'thu' if x == 4
                                                            else 'fri' if x == 5
                                                            else 'sat')

# %%
"""
"temp":  
Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale) 
(so t = temp * (t_max - t_min) + t_min)

"atemp": Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
t = temp * (t_max - t_min) + t_min)
"""

t_min = -8.0
t_max = 39.0

df_daily['temp'] = df_daily['temp'].apply(lambda x: round (x * (t_max - t_min) + t_min, 1) )
df_hourly['temp'] = df_hourly['temp'].apply(lambda x: round (x * (t_max - t_min) + t_min, 1))

# %%
"""
"temp":  
Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale) 
(so t = temp * (t_max - t_min) + t_min)

"atemp": Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
t = temp * (t_max - t_min) + t_min)
"""

t_min = -16.0
t_max = 50.0

df_daily['app_temp'] = df_daily['app_temp'].apply(lambda x: round (x * (t_max - t_min) + t_min, 1) )
df_hourly['app_temp'] = df_hourly['app_temp'].apply(lambda x: round (x * (t_max - t_min) + t_min, 1))

# %%
"""
"hum": Normalized humidity. The values are divided to 100 (max) <br>

"windspeed": Normalized wind speed. The values are divided to 67 (max) <br>
"""

df_daily['humidity'] = df_daily['humidity'].apply(lambda x: round (x * 100, 1) )
df_hourly['humidity'] = df_hourly['humidity'].apply(lambda x: round (x * 100, 1))

df_daily['wind_speed'] = df_daily['wind_speed'].apply(lambda x: round (x * 67, 1) )
df_hourly['wind_speed'] = df_hourly['wind_speed'].apply(lambda x: round (x * 67, 1))

# %%
df_daily.head()
df_hourly.head()
# Out:
#          date  season  year  month  hour holiday day_of_week  work_day  \
# 0  2011-01-01       1     0      1     0      no         sat         0
# 1  2011-01-01       1     0      1     1      no         sat         0
# 2  2011-01-01       1     0      1     2      no         sat         0
# 3  2011-01-01       1     0      1     3      no         sat         0
# 4  2011-01-01       1     0      1     4      no         sat         0
#
#    weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 0            1   3.3       3.0      81.0         0.0       3          13
# 1            1   2.3       2.0      80.0         0.0       8          32
# 2            1   2.3       2.0      80.0         0.0       5          27
# 3            1   3.3       3.0      75.0         0.0       3          10
# 4            1   3.3       3.0      75.0         0.0       0           1
#
#    total
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
df_daily['date'] = pd.to_datetime(df_daily['date'])
df_hourly['date'] = pd.to_datetime(df_hourly['date'])

# %%
df_daily.info()
df_hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         731 non-null    datetime64[ns]
#  1   season       731 non-null    int64
#  2   year         731 non-null    int64
#  3   month        731 non-null    int64
#  4   holiday      731 non-null    object
#  5   day_of_week  731 non-null    object
#  6   work_day     731 non-null    int64
#  7   weather_sit  731 non-null    int64
#  8   temp         731 non-null    float64
#  9   app_temp     731 non-null    float64
#  10  humidity     731 non-null    float64
#  11  wind_speed   731 non-null    float64
#  12  casual       731 non-null    int64
#  13  registered   731 non-null    int64
#  14  total        731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(2)
# memory usage: 85.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         17379 non-null  datetime64[ns]
#  1   season       17379 non-null  int64
#  2   year         17379 non-null  int64
#  3   month        17379 non-null  int64
#  4   hour         17379 non-null  int64
#  5   holiday      17379 non-null  object
#  6   day_of_week  17379 non-null  object
#  7   work_day     17379 non-null  int64
#  8   weather_sit  17379 non-null  int64
#  9   temp         17379 non-null  float64
#  10  app_temp     17379 non-null  float64
#  11  humidity     17379 non-null  float64
#  12  wind_speed   17379 non-null  float64
#  13  casual       17379 non-null  int64
#  14  registered   17379 non-null  int64
#  15  total        17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(9), object(2)
# memory usage: 2.1+ MB

# %%
df_daily.head()
df_hourly.head()
# Out:
#         date  season  year  month  hour holiday day_of_week  work_day  \
# 0 2011-01-01       1     0      1     0      no         sat         0
# 1 2011-01-01       1     0      1     1      no         sat         0
# 2 2011-01-01       1     0      1     2      no         sat         0
# 3 2011-01-01       1     0      1     3      no         sat         0
# 4 2011-01-01       1     0      1     4      no         sat         0
#
#    weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 0            1   3.3       3.0      81.0         0.0       3          13
# 1            1   2.3       2.0      80.0         0.0       8          32
# 2            1   2.3       2.0      80.0         0.0       5          27
# 3            1   3.3       3.0      75.0         0.0       3          10
# 4            1   3.3       3.0      75.0         0.0       0           1
#
#    total
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
df_daily['work_day'] = df_daily['work_day'].apply(lambda x: 'yes' if x == 1 else 'no')
df_hourly['work_day'] = df_hourly['work_day'].apply(lambda x: 'yes' if x == 1 else 'no')

# %%
df_daily.head(20)
df_hourly.head(20)
# Out:
#          date  season  year  month  hour holiday day_of_week work_day  \
# 0  2011-01-01       1     0      1     0      no         sat       no
# 1  2011-01-01       1     0      1     1      no         sat       no
# 2  2011-01-01       1     0      1     2      no         sat       no
# 3  2011-01-01       1     0      1     3      no         sat       no
# 4  2011-01-01       1     0      1     4      no         sat       no
# 5  2011-01-01       1     0      1     5      no         sat       no
# 6  2011-01-01       1     0      1     6      no         sat       no
# 7  2011-01-01       1     0      1     7      no         sat       no
# 8  2011-01-01       1     0      1     8      no         sat       no
# 9  2011-01-01       1     0      1     9      no         sat       no
# 10 2011-01-01       1     0      1    10      no         sat       no
# 11 2011-01-01       1     0      1    11      no         sat       no
# 12 2011-01-01       1     0      1    12      no         sat       no
# 13 2011-01-01       1     0      1    13      no         sat       no
# 14 2011-01-01       1     0      1    14      no         sat       no
# 15 2011-01-01       1     0      1    15      no         sat       no
# 16 2011-01-01       1     0      1    16      no         sat       no
# 17 2011-01-01       1     0      1    17      no         sat       no
# 18 2011-01-01       1     0      1    18      no         sat       no
# 19 2011-01-01       1     0      1    19      no         sat       no
#
#     weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 0             1   3.3       3.0      81.0         0.0       3          13
# 1             1   2.3       2.0      80.0         0.0       8          32
# 2             1   2.3       2.0      80.0         0.0       5          27
# 3             1   3.3       3.0      75.0         0.0       3          10
# 4             1   3.3       3.0      75.0         0.0       0           1
# 5             2   3.3       1.0      75.0         6.0       0           1
# 6             1   2.3       2.0      80.0         0.0       2           0
# 7             1   1.4       1.0      86.0         0.0       1           2
# 8             1   3.3       3.0      75.0         0.0       1           7
# 9             1   7.0       7.0      76.0         0.0       8           6
# 10            1   9.9      10.0      76.0        17.0      12          24
# 11            1   8.9       6.0      81.0        19.0      26          30
# 12            1  11.7      12.0      77.0        19.0      29          55
# 13            2  13.6      14.0      72.0        20.0      47          47
# 14            2  13.6      14.0      72.0        19.0      35          71
# 15            2  12.7      13.0      77.0        20.0      40          70
# 16            2  11.7      12.0      82.0        20.0      41          52
# 17            2  12.7      13.0      82.0        19.0      15          52
# 18            3  11.7      12.0      88.0        17.0       9          26
# 19            3  11.7      12.0      88.0        17.0       6          31
#
#     total
# 0      16
# 1      40
# 2      32
# 3      13
# 4       1
# 5       1
# 6       2
# 7       3
# 8       8
# 9      14
# 10     36
# 11     56
# 12     84
# 13     94
# 14    106
# 15    110
# 16     93
# 17     67
# 18     35
# 19     37

# %%
df_daily['year'] = df_daily['date'].dt.year
df_hourly['year'] = df_hourly['date'].dt.year

# %%
df_daily.head()
df_hourly.head()
# Out:
#         date  season  year  month  hour holiday day_of_week work_day  \
# 0 2011-01-01       1  2011      1     0      no         sat       no
# 1 2011-01-01       1  2011      1     1      no         sat       no
# 2 2011-01-01       1  2011      1     2      no         sat       no
# 3 2011-01-01       1  2011      1     3      no         sat       no
# 4 2011-01-01       1  2011      1     4      no         sat       no
#
#    weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 0            1   3.3       3.0      81.0         0.0       3          13
# 1            1   2.3       2.0      80.0         0.0       8          32
# 2            1   2.3       2.0      80.0         0.0       5          27
# 3            1   3.3       3.0      75.0         0.0       3          10
# 4            1   3.3       3.0      75.0         0.0       0           1
#
#    total
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
# Change "weather_sit" column

# 1: Clear, Few clouds, Partly cloudy, Partly cloudy 
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist 
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds 
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog 

# Rename as follows: 

# 1: Clear
# 2: Misty
# 3: Bit wet
# 4: Very wet


df_daily['weather_sit'] = df_daily['weather_sit'].apply(lambda x: 'clear' if x == 1
                                                                else 'misty' if x == 2
                                                                else 'bit wet' if x == 3
                                                                else 'very wet')

df_hourly['weather_sit'] = df_hourly['weather_sit'].apply(lambda x: 'clear' if x == 1
                                                                else 'misty' if x == 2
                                                                else 'bit wet' if x == 3
                                                                else 'very wet')

# %%
df_daily.head()
df_hourly.head()
# Out:
#         date  season  year  month  hour holiday day_of_week work_day  \
# 0 2011-01-01       1  2011      1     0      no         sat       no
# 1 2011-01-01       1  2011      1     1      no         sat       no
# 2 2011-01-01       1  2011      1     2      no         sat       no
# 3 2011-01-01       1  2011      1     3      no         sat       no
# 4 2011-01-01       1  2011      1     4      no         sat       no
#
#   weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  total
# 0       clear   3.3       3.0      81.0         0.0       3          13     16
# 1       clear   2.3       2.0      80.0         0.0       8          32     40
# 2       clear   2.3       2.0      80.0         0.0       5          27     32
# 3       clear   3.3       3.0      75.0         0.0       3          10     13
# 4       clear   3.3       3.0      75.0         0.0       0           1      1

# %%
# "season": (1:winter, 2:spring, 3:summer, 4:fall)

df_daily['season'] = df_daily['season'].apply(lambda x: 'winter' if x == 1
                                                    else 'spring' if x == 2
                                                    else 'summer' if x == 3
                                                    else 'autumn')

# %%
# "season": (1:winter, 2:spring, 3:summer, 4:fall)

df_hourly['season'] = df_hourly['season'].apply(lambda x: 'winter' if x == 1
                                                    else 'spring' if x == 2
                                                    else 'summer' if x == 3
                                                    else 'autumn')

# %%
# Check the boundaries for the seasons in 2011

spring_first = df_daily [(df_daily['date'].dt.year == 2011) & (df_daily['season'] == 'spring')].iloc[0]['date']
spring_last = df_daily [(df_daily['date'].dt.year == 2011) & (df_daily['season'] == 'spring')].iloc[-1]['date']

summer_first = df_daily [(df_daily['date'].dt.year == 2011) & (df_daily['season'] == 'summer')].iloc[0]['date']
summer_last = df_daily [(df_daily['date'].dt.year == 2011) & (df_daily['season'] == 'summer')].iloc[-1]['date']

autumn_first = df_daily [(df_daily['date'].dt.year == 2011) & (df_daily['season'] == 'autumn')].iloc[0]['date']
autumn_last = df_daily [(df_daily['date'].dt.year == 2011) & (df_daily['season'] == 'autumn')].iloc[-1]['date']

spring_first, spring_last, summer_first, summer_last, autumn_first, autumn_last
# Out:
# (Timestamp('2011-03-21 00:00:00'),
#  Timestamp('2011-06-20 00:00:00'),
#  Timestamp('2011-06-21 00:00:00'),
#  Timestamp('2011-09-22 00:00:00'),
#  Timestamp('2011-09-23 00:00:00'),
#  Timestamp('2011-12-20 00:00:00'))

# %%
# Season boundaries for 2011:

# spring: 03-21 to 06-20
# summer: 06-21 to 09-22
# autumn: 09-03 to 12-20
# winter: 12-21 to 03-20

# %%
# Check the boundaries for the seasons in 2012

spring_first = df_daily [(df_daily['date'].dt.year == 2012) & (df_daily['season'] == 'spring')].iloc[0]['date']
spring_last = df_daily [(df_daily['date'].dt.year == 2012) & (df_daily['season'] == 'spring')].iloc[-1]['date']

summer_first = df_daily [(df_daily['date'].dt.year == 2012) & (df_daily['season'] == 'summer')].iloc[0]['date']
summer_last = df_daily [(df_daily['date'].dt.year == 2012) & (df_daily['season'] == 'summer')].iloc[-1]['date']

autumn_first = df_daily [(df_daily['date'].dt.year == 2012) & (df_daily['season'] == 'autumn')].iloc[0]['date']
autumn_last = df_daily [(df_daily['date'].dt.year == 2012) & (df_daily['season'] == 'autumn')].iloc[-1]['date']

spring_first, spring_last, summer_first, summer_last, autumn_first, autumn_last
# Out:
# (Timestamp('2012-03-21 00:00:00'),
#  Timestamp('2012-06-20 00:00:00'),
#  Timestamp('2012-06-21 00:00:00'),
#  Timestamp('2012-09-22 00:00:00'),
#  Timestamp('2012-09-23 00:00:00'),
#  Timestamp('2012-12-20 00:00:00'))

# %%
# Good. So the boundaries are the same for both years. 

# How about for the hourly data?

# %%
# Check season boundaries for df_hourly, in year 2011

spring_first = df_hourly [(df_hourly['date'].dt.year == 2011) & (df_hourly['season'] == 'spring')].iloc[0]['date']
spring_last = df_hourly [(df_hourly['date'].dt.year == 2011) & (df_hourly['season'] == 'spring')].iloc[-1]['date']

summer_first = df_hourly [(df_hourly['date'].dt.year == 2011) & (df_hourly['season'] == 'summer')].iloc[0]['date']
summer_last = df_hourly [(df_hourly['date'].dt.year == 2011) & (df_hourly['season'] == 'summer')].iloc[-1]['date']

autumn_first = df_hourly [(df_hourly['date'].dt.year == 2011) & (df_hourly['season'] == 'autumn')].iloc[0]['date']
autumn_last = df_hourly [(df_hourly['date'].dt.year == 2011) & (df_hourly['season'] == 'autumn')].iloc[-1]['date']

spring_first, spring_last, summer_first, summer_last, autumn_first, autumn_last
# Out:
# (Timestamp('2011-03-21 00:00:00'),
#  Timestamp('2011-06-20 00:00:00'),
#  Timestamp('2011-06-21 00:00:00'),
#  Timestamp('2011-09-22 00:00:00'),
#  Timestamp('2011-09-23 00:00:00'),
#  Timestamp('2011-12-20 00:00:00'))

# %%
# Check season boundaries for df_hourly, in year 2012

spring_first = df_hourly [(df_hourly['date'].dt.year == 2012) & (df_hourly['season'] == 'spring')].iloc[0]['date']
spring_last = df_hourly [(df_hourly['date'].dt.year == 2012) & (df_hourly['season'] == 'spring')].iloc[-1]['date']

summer_first = df_hourly [(df_hourly['date'].dt.year == 2012) & (df_hourly['season'] == 'summer')].iloc[0]['date']
summer_last = df_hourly [(df_hourly['date'].dt.year == 2012) & (df_hourly['season'] == 'summer')].iloc[-1]['date']

autumn_first = df_hourly [(df_hourly['date'].dt.year == 2012) & (df_hourly['season'] == 'autumn')].iloc[0]['date']
autumn_last = df_hourly [(df_hourly['date'].dt.year == 2012) & (df_hourly['season'] == 'autumn')].iloc[-1]['date']

spring_first, spring_last, summer_first, summer_last, autumn_first, autumn_last
# Out:
# (Timestamp('2012-03-21 00:00:00'),
#  Timestamp('2012-06-20 00:00:00'),
#  Timestamp('2012-06-21 00:00:00'),
#  Timestamp('2012-09-22 00:00:00'),
#  Timestamp('2012-09-23 00:00:00'),
#  Timestamp('2012-12-20 00:00:00'))

# %%
# OK. Seasonal boundaries are the same for both data sets. 

# Let's now change them to something more reasonable.

# %%
# Daily data

spring_mask = ((df_daily['date'].dt.month >= 3) & (df_daily['date'].dt.day >= 1)) & ((df_daily['date'].dt.month <= 5) & (df_daily['date'].dt.day <= 31))
summer_mask = ((df_daily['date'].dt.month >= 6) & (df_daily['date'].dt.day >= 1)) & ((df_daily['date'].dt.month <= 8) & (df_daily['date'].dt.day <= 31))
autumn_mask = ((df_daily['date'].dt.month >= 9) & (df_daily['date'].dt.day >= 1)) & ((df_daily['date'].dt.month <= 11) & (df_daily['date'].dt.day <= 30))
winter_mask = (((df_daily['date'].dt.month >= 12) & (df_daily['date'].dt.day >= 1)) & ((df_daily['date'].dt.month <= 12) & (df_daily['date'].dt.day <= 31))) |(((df_daily['date'].dt.month >= 1) & (df_daily['date'].dt.day >= 1)) & ((df_daily['date'].dt.month <= 2) & (df_daily['date'].dt.day <= 29)))


df_daily.loc[spring_mask, 'season'] = 'spring'
df_daily.loc[summer_mask, 'season'] = 'summer'
df_daily.loc[autumn_mask, 'season'] = 'autumn'
df_daily.loc[winter_mask, 'season'] = 'winter'

# %%
# Hourly data

spring_mask = ((df_hourly['date'].dt.month >= 3) & (df_hourly['date'].dt.day >= 1)) & ((df_hourly['date'].dt.month <= 5) & (df_hourly['date'].dt.day <= 31))
summer_mask = ((df_hourly['date'].dt.month >= 6) & (df_hourly['date'].dt.day >= 1)) & ((df_hourly['date'].dt.month <= 8) & (df_hourly['date'].dt.day <= 31))
autumn_mask = ((df_hourly['date'].dt.month >= 9) & (df_hourly['date'].dt.day >= 1)) & ((df_hourly['date'].dt.month <= 11) & (df_hourly['date'].dt.day <= 30))
winter_mask = (((df_hourly['date'].dt.month >= 12) & (df_hourly['date'].dt.day >= 1)) & ((df_hourly['date'].dt.month <= 12) & (df_hourly['date'].dt.day <= 31))) |(((df_hourly['date'].dt.month >= 1) & (df_hourly['date'].dt.day >= 1)) & ((df_hourly['date'].dt.month <= 2) & (df_hourly['date'].dt.day <= 29)))


df_hourly.loc[spring_mask, 'season'] = 'spring'
df_hourly.loc[summer_mask, 'season'] = 'summer'
df_hourly.loc[autumn_mask, 'season'] = 'autumn'
df_hourly.loc[winter_mask, 'season'] = 'winter'

# %%
df_hourly[df_hourly['date'].dt.month == 9]
# Out:
#             date  season  year  month  hour holiday day_of_week work_day  \
# 5725  2011-09-01  autumn  2011      9     0      no         thu      yes
# 5726  2011-09-01  autumn  2011      9     1      no         thu      yes
# 5727  2011-09-01  autumn  2011      9     2      no         thu      yes
# 5728  2011-09-01  autumn  2011      9     3      no         thu      yes
# 5729  2011-09-01  autumn  2011      9     4      no         thu      yes
# ...          ...     ...   ...    ...   ...     ...         ...      ...
# 15206 2012-09-30  autumn  2012      9    19      no         sun       no
# 15207 2012-09-30  autumn  2012      9    20      no         sun       no
# 15208 2012-09-30  autumn  2012      9    21      no         sun       no
# 15209 2012-09-30  autumn  2012      9    22      no         sun       no
# 15210 2012-09-30  autumn  2012      9    23      no         sun       no
#
#       weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 5725        clear  20.2      22.0      78.0         7.0      18          33
# 5726        clear  20.2      23.0      73.0         6.0       7          14
# 5727        clear  19.3      20.0      78.0         6.0      14          11
# 5728        clear  19.3      20.0      78.0         6.0       7           7
# 5729        clear  18.3      19.0      83.0         6.0       0           7
# ...           ...   ...       ...       ...         ...     ...         ...
# 15206     bit wet  15.5      16.0      72.0         9.0      34         223
# 15207     bit wet  15.5      16.0      72.0         9.0      31         163
# 15208       clear  15.5      16.0      68.0         0.0      19         104
# 15209       clear  14.6      15.0      72.0         0.0      15          76
# 15210       clear  14.6      15.0      72.0         6.0       8          49
#
#        total
# 5725      51
# 5726      21
# 5727      25
# 5728      14
# 5729       7
# ...      ...
# 15206    257
# 15207    194
# 15208    123
# 15209     91
# 15210     57
#
# [1437 rows x 16 columns]

# %% [markdown]
# Add dew point to each row

# %%
def get_dew_point_c(t_air_c, rel_humidity):
    """Compute the dew point in degrees Celsius
    :param t_air_c: current ambient temperature in degrees Celsius
    :type t_air_c: float
    :param rel_humidity: relative humidity in %
    :type rel_humidity: float
    :return: the dew point in degrees Celsius
    :rtype: float
    """
    A = 17.27
    B = 237.7
    alpha = np.divide((A * t_air_c), (B +t_air_c)) + np.log(rel_humidity/100.0)
    return np.divide (B*alpha, (A -alpha))

# %%
df_hourly['dew_point'] = get_dew_point_c(df_hourly['temp'], df_hourly['humidity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_daily['dew_point'] = get_dew_point_c(df_daily['temp'], df_daily['humidity'])

# %%
plt.hist(df_hourly['dew_point'])
# Out:
# (array([  79.,  345.,  978., 1990., 2285., 2324., 2648., 2712., 3414.,
#          582.]),
#  array([-20.27618611, -15.6898986 , -11.1036111 ,  -6.5173236 ,
#          -1.9310361 ,   2.65525141,   7.24153891,  11.82782641,
#          16.41411391,  21.00040142,  25.58668892]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_daily['dew_point'])
# Out:
# (array([  4.,  23.,  45.,  86.,  93.,  93., 100.,  94., 131.,  61.]),
#  array([-16.67056588, -12.6049651 ,  -8.53936431,  -4.47376353,
#          -0.40816275,   3.65743804,   7.72303882,  11.7886396 ,
#          15.85424038,  19.91984117,  23.98544195]),
#  <BarContainer object of 10 artists>)

# %%
# Divide 'app_temp' (apparent temperature, or heat index) into categories: 
"""
– 0: 'below 0'
0 – 10: '0 to 10'
10 – 20: '10 to 20'
20 – 30: '20 to 30'
30 – : 'above 30'
"""

df_daily['app_temp_cat'] = df_daily['app_temp'].apply(lambda x: 'below -5' if x <= -5
                                                            else '-5 to 5' if x <= 5
                                                            else '5 to 15' if x <= 15
                                                            else '15 to 25' if x <= 25
                                                            else '25 to 35' if x <= 35
                                                            else '35 or higher')

df_hourly['app_temp_cat'] = df_hourly['app_temp'].apply(lambda x: 'below -5' if x <= -5
                                                            else '-5 to 5' if x <= 5
                                                            else '5 to 15' if x <= 15
                                                            else '15 to 25' if x <= 25
                                                            else '25 to 35' if x <= 35
                                                            else '35 or higher')

# %%
df_daily[df_daily['season'] == 'summer'].head()
df_hourly[df_hourly['season'] == 'summer'].head()
# Out:
#            date  season  year  month  hour holiday day_of_week work_day  \
# 3530 2011-06-01  summer  2011      6     0      no         wed      yes
# 3531 2011-06-01  summer  2011      6     1      no         wed      yes
# 3532 2011-06-01  summer  2011      6     2      no         wed      yes
# 3533 2011-06-01  summer  2011      6     3      no         wed      yes
# 3534 2011-06-01  summer  2011      6     4      no         wed      yes
#
#      weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 3530       clear  24.9      28.0      79.0        11.0       9          25
# 3531       clear  24.9      28.0      84.0        17.0       8           9
# 3532       clear  24.9      28.0      79.0        11.0       0           3
# 3533       clear  24.0      26.0      89.0        13.0       0           6
# 3534       misty  24.0      26.0      89.0        15.0       0           4
#
#       total  dew_point app_temp_cat
# 3530     34  20.999064     25 to 35
# 3531     17  22.003448     25 to 35
# 3532      3  20.999064     25 to 35
# 3533      6  22.070151     25 to 35
# 3534      4  22.070151     25 to 35

# %%
df_daily['year_month'] = df_daily['date'].dt.to_period('M')
df_hourly['year_month'] = df_hourly['date'].dt.to_period('M')

# %%
df_daily.tail()
df_hourly.head()
# Out:
#         date  season  year  month  hour holiday day_of_week work_day  \
# 0 2011-01-01  winter  2011      1     0      no         sat       no
# 1 2011-01-01  winter  2011      1     1      no         sat       no
# 2 2011-01-01  winter  2011      1     2      no         sat       no
# 3 2011-01-01  winter  2011      1     3      no         sat       no
# 4 2011-01-01  winter  2011      1     4      no         sat       no
#
#   weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 0       clear   3.3       3.0      81.0         0.0       3          13
# 1       clear   2.3       2.0      80.0         0.0       8          32
# 2       clear   2.3       2.0      80.0         0.0       5          27
# 3       clear   3.3       3.0      75.0         0.0       3          10
# 4       clear   3.3       3.0      75.0         0.0       0           1
#
#    total  dew_point app_temp_cat year_month
# 0     16   0.355031      -5 to 5    2011-01
# 1     40  -0.790695      -5 to 5    2011-01
# 2     32  -0.790695      -5 to 5    2011-01
# 3     13  -0.702688      -5 to 5    2011-01
# 4      1  -0.702688      -5 to 5    2011-01

# %%
# Column with calendar_week

df_daily['calendar_week'] = df_daily['date'].dt.week
# Out:
# /var/folders/68/lmdx_4hd4msbstk8y2t5phyh0000gn/T/ipykernel_5165/2712438839.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df_daily['calendar_week'] = df_daily['date'].dt.week

# %%
df_daily.head()
# Out:
#         date  season  year  month holiday day_of_week work_day weather_sit  \
# 0 2011-01-01  winter  2011      1      no         sat       no       misty
# 1 2011-01-02  winter  2011      1      no         sun       no       misty
# 2 2011-01-03  winter  2011      1      no         mon      yes       clear
# 3 2011-01-04  winter  2011      1      no         tue      yes       clear
# 4 2011-01-05  winter  2011      1      no         wed      yes       clear
#
#    temp  app_temp  humidity  wind_speed  casual  registered  total  dew_point  \
# 0   8.2       8.0      80.6        10.7     331         654    985   5.063729
# 1   9.1       7.3      69.6        16.7     131         670    801   3.837369
# 2   1.2      -3.5      43.7        16.6     120        1229   1349  -9.780283
# 3   1.4      -2.0      59.0        10.7     108        1454   1562  -5.728918
# 4   2.7      -0.9      43.7        12.5      82        1518   1600  -8.415394
#
#   app_temp_cat year_month  calendar_week
# 0      5 to 15    2011-01             52
# 1      5 to 15    2011-01             52
# 2      -5 to 5    2011-01              1
# 3      -5 to 5    2011-01              1
# 4      -5 to 5    2011-01              1

# %%
df_hourly['hour'].value_counts().sort_index()
# Out:
# 0     726
# 1     724
# 2     715
# 3     697
# 4     697
# 5     717
# 6     725
# 7     727
# 8     727
# 9     727
# 10    727
# 11    727
# 12    728
# 13    729
# 14    729
# 15    729
# 16    730
# 17    730
# 18    728
# 19    728
# 20    728
# 21    728
# 22    728
# 23    728
# Name: hour, dtype: int64

# %%
df_hourly_missing_vals = df_hourly['date'].value_counts().to_frame()

# %%
df_hourly_missing_vals.columns
# Out:
# Index(['date'], dtype='object')

# %%
df_hourly_missing_vals = df_hourly_missing_vals.rename(columns = {'date':'num_vals'})

# %%
df_hourly_missing_vals['missing_vals'] = df_hourly_missing_vals['num_vals'].apply(lambda x: 24 - x)

# %%
df_hourly_missing_vals[df_hourly_missing_vals['missing_vals'] != 0]
# Out:
#             num_vals  missing_vals
# 2011-01-05        23             1
# 2011-02-09        23             1
# 2011-10-19        23             1
# 2011-01-06        23             1
# 2012-11-29        23             1
# ...              ...           ...
# 2011-01-26        16             8
# 2011-01-18        12            12
# 2012-10-30        11            13
# 2011-01-27         8            16
# 2012-10-29         1            23
#
# [76 rows x 2 columns]

# %%
plt.figure(figsize = (10,10))
plt.plot(df_hourly_missing_vals[df_hourly_missing_vals['missing_vals'] != 0].index, df_hourly_missing_vals[df_hourly_missing_vals['missing_vals'] != 0].missing_vals)
plt.xticks(rotation = 90)
plt.show()

# %%
df_hourly_missing_vals[df_hourly_missing_vals['missing_vals'] > 1]
# Out:
#             num_vals  missing_vals
# 2011-01-03        22             2
# 2011-02-11        22             2
# 2011-03-10        22             2
# 2011-01-11        22             2
# 2011-02-28        22             2
# 2011-01-12        22             2
# 2011-08-27        18             6
# 2011-02-22        18             6
# 2011-08-28        17             7
# 2011-01-26        16             8
# 2011-01-18        12            12
# 2012-10-30        11            13
# 2011-01-27         8            16
# 2012-10-29         1            23

# %% [markdown]
# <h5> 2012-10-29 could be problematic. It only has hourly info for midnight (0:00) </h5>

# %%
df_hourly[df_hourly['date'] == '2012-10-29']
# Out:
#             date  season  year  month  hour holiday day_of_week work_day  \
# 15883 2012-10-29  autumn  2012     10     0      no         mon      yes
#
#       weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 15883     bit wet  12.7      13.0      88.0        24.0       2          20
#
#        total  dew_point app_temp_cat year_month
# 15883     22  10.762605      5 to 15    2012-10

# %% [markdown]
# <h5> 2011-01-27 could be problematic. It only has hourly info from 16:00 onwards </h5>

# %%
df_hourly[df_hourly['date'] == '2011-01-27']
# Out:
#           date  season  year  month  hour holiday day_of_week work_day  \
# 587 2011-01-27  winter  2011      1    16      no         thu      yes
# 588 2011-01-27  winter  2011      1    17      no         thu      yes
# 589 2011-01-27  winter  2011      1    18      no         thu      yes
# 590 2011-01-27  winter  2011      1    19      no         thu      yes
# 591 2011-01-27  winter  2011      1    20      no         thu      yes
# 592 2011-01-27  winter  2011      1    21      no         thu      yes
# 593 2011-01-27  winter  2011      1    22      no         thu      yes
# 594 2011-01-27  winter  2011      1    23      no         thu      yes
#
#     weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 587       clear   2.3      -1.0      55.0        13.0       1          23
# 588       clear   2.3      -0.0      55.0         7.0       2          82
# 589       clear   1.4      -1.0      69.0         6.0       3         101
# 590       clear   1.4      -1.0      69.0         6.0       3          76
# 591       clear   0.5      -2.0      74.0         6.0       4          55
# 592       clear   0.5      -2.0      74.0         6.0       2          36
# 593       clear   0.5      -2.0      74.0         6.0       0          27
# 594       clear   0.5      -3.0      80.0        11.0       0          16
#
#      total  dew_point app_temp_cat year_month
# 587     24  -5.805196      -5 to 5    2011-01
# 588     84  -5.805196      -5 to 5    2011-01
# 589    104  -3.658245      -5 to 5    2011-01
# 590     79  -3.658245      -5 to 5    2011-01
# 591     59  -3.590324      -5 to 5    2011-01
# 592     38  -3.590324      -5 to 5    2011-01
# 593     27  -3.590324      -5 to 5    2011-01
# 594     16  -2.544803      -5 to 5    2011-01

# %% [markdown]
# <h5> 2012-10-30 also has missing rows, but we still have rows from 1pm onwards, which isn't so bad </h5> <br>
# However, the temperature values look corrupted. We have a bunch of "6.1"s, and a single "15.5". <br>
# Could compare with 2012-10-29, 2012-10,28, 2012-10-31 and impute using average? <br>
# But 2012-10-29 is also missing most of its rows. So will have to impute using 2012-10-28 and 2012-10-31

# %%
df_hourly[df_hourly['date'] == '2012-10-30']
# Out:
#             date  season  year  month  hour holiday day_of_week work_day  \
# 15884 2012-10-30  autumn  2012     10    13      no         tue      yes
# 15885 2012-10-30  autumn  2012     10    14      no         tue      yes
# 15886 2012-10-30  autumn  2012     10    15      no         tue      yes
# 15887 2012-10-30  autumn  2012     10    16      no         tue      yes
# 15888 2012-10-30  autumn  2012     10    17      no         tue      yes
# 15889 2012-10-30  autumn  2012     10    18      no         tue      yes
# 15890 2012-10-30  autumn  2012     10    19      no         tue      yes
# 15891 2012-10-30  autumn  2012     10    20      no         tue      yes
# 15892 2012-10-30  autumn  2012     10    21      no         tue      yes
# 15893 2012-10-30  autumn  2012     10    22      no         tue      yes
# 15894 2012-10-30  autumn  2012     10    23      no         tue      yes
#
#       weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 15884     bit wet   6.1       2.0      81.0        24.0      11         105
# 15885     bit wet   6.1       2.0      81.0        24.0       8         118
# 15886     bit wet   6.1       3.0      87.0        17.0      10         114
# 15887     bit wet   6.1       3.0      87.0        17.0      15          83
# 15888     bit wet   6.1       3.0      87.0        15.0      19         105
# 15889     bit wet   6.1       4.0      87.0         9.0       4         139
# 15890       misty  15.5      16.0      68.0        13.0       6         109
# 15891       misty   6.1       3.0      81.0        13.0       5          76
# 15892       misty   6.1       5.0      87.0         7.0       4          60
# 15893       clear   6.1       4.0      81.0         9.0       2          64
# 15894       clear   6.1       4.0      81.0         9.0       3          36
#
#        total  dew_point app_temp_cat year_month
# 15884    116   3.086630      -5 to 5    2012-10
# 15885    126   3.086630      -5 to 5    2012-10
# 15886    124   4.100131      -5 to 5    2012-10
# 15887     98   4.100131      -5 to 5    2012-10
# 15888    124   4.100131      -5 to 5    2012-10
# 15889    143   4.100131      -5 to 5    2012-10
# 15890    115   9.616938     15 to 25    2012-10
# 15891     81   3.086630      -5 to 5    2012-10
# 15892     64   4.100131      -5 to 5    2012-10
# 15893     66   3.086630      -5 to 5    2012-10
# 15894     39   3.086630      -5 to 5    2012-10

# %%
df_hourly[df_hourly['date'] == '2012-10-29']
# Out:
#             date  season  year  month  hour holiday day_of_week work_day  \
# 15883 2012-10-29  autumn  2012     10     0      no         mon      yes
#
#       weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 15883     bit wet  12.7      13.0      88.0        24.0       2          20
#
#        total  dew_point app_temp_cat year_month
# 15883     22  10.762605      5 to 15    2012-10

# %%
df_hourly[df_hourly['date'] == '2012-10-28']
# Out:
#             date  season  year  month  hour holiday day_of_week work_day  \
# 15859 2012-10-28  autumn  2012     10     0      no         sun       no
# 15860 2012-10-28  autumn  2012     10     1      no         sun       no
# 15861 2012-10-28  autumn  2012     10     2      no         sun       no
# 15862 2012-10-28  autumn  2012     10     3      no         sun       no
# 15863 2012-10-28  autumn  2012     10     4      no         sun       no
# 15864 2012-10-28  autumn  2012     10     5      no         sun       no
# 15865 2012-10-28  autumn  2012     10     6      no         sun       no
# 15866 2012-10-28  autumn  2012     10     7      no         sun       no
# 15867 2012-10-28  autumn  2012     10     8      no         sun       no
# 15868 2012-10-28  autumn  2012     10     9      no         sun       no
# 15869 2012-10-28  autumn  2012     10    10      no         sun       no
# 15870 2012-10-28  autumn  2012     10    11      no         sun       no
# 15871 2012-10-28  autumn  2012     10    12      no         sun       no
# 15872 2012-10-28  autumn  2012     10    13      no         sun       no
# 15873 2012-10-28  autumn  2012     10    14      no         sun       no
# 15874 2012-10-28  autumn  2012     10    15      no         sun       no
# 15875 2012-10-28  autumn  2012     10    16      no         sun       no
# 15876 2012-10-28  autumn  2012     10    17      no         sun       no
# 15877 2012-10-28  autumn  2012     10    18      no         sun       no
# 15878 2012-10-28  autumn  2012     10    19      no         sun       no
# 15879 2012-10-28  autumn  2012     10    20      no         sun       no
# 15880 2012-10-28  autumn  2012     10    21      no         sun       no
# 15881 2012-10-28  autumn  2012     10    22      no         sun       no
# 15882 2012-10-28  autumn  2012     10    23      no         sun       no
#
#       weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 15859     bit wet  16.4      17.0      68.0        20.0      20          97
# 15860       misty  15.5      16.0      72.0        19.0      22         111
# 15861       misty  15.5      16.0      68.0        20.0      17          99
# 15862       misty  15.5      16.0      63.0        22.0      18          61
# 15863       misty  15.5      16.0      63.0        24.0       1          19
# 15864       misty  15.5      16.0      63.0        20.0       6          22
# 15865       misty  15.5      16.0      59.0        22.0       7          32
# 15866       misty  15.5      16.0      59.0        20.0      17          48
# 15867       misty  15.5      16.0      59.0        37.0      55         118
# 15868       misty  15.5      16.0      55.0        28.0     124         206
# 15869       misty  14.6      15.0      51.0        28.0     120         314
# 15870       misty  15.5      16.0      51.0        26.0     110         352
# 15871       misty  14.6      15.0      59.0        33.0     118         373
# 15872       misty  14.6      15.0      59.0        28.0      75         316
# 15873       misty  15.5      16.0      59.0        30.0      98         304
# 15874       misty  15.5      16.0      63.0        33.0      76         225
# 15875     bit wet  14.6      15.0      67.0        31.0      42         251
# 15876     bit wet  13.6      14.0      77.0        35.0      37         188
# 15877     bit wet  11.7      12.0      94.0        33.0      18         136
# 15878     bit wet  11.7      12.0      94.0        24.0       7          47
# 15879     bit wet  11.7      12.0      94.0        31.0       4          51
# 15880     bit wet  12.7      13.0      88.0        28.0       2          44
# 15881     bit wet  12.7      13.0      88.0        24.0       2          35
# 15882     bit wet  11.7      12.0      94.0        24.0       2          12
#
#        total  dew_point app_temp_cat year_month
# 15859    117  10.475530     15 to 25    2012-10
# 15860    133  10.471541     15 to 25    2012-10
# 15861    116   9.616938     15 to 25    2012-10
# 15862     79   8.484193     15 to 25    2012-10
# 15863     20   8.484193     15 to 25    2012-10
# 15864     28   8.484193     15 to 25    2012-10
# 15865     39   7.519521     15 to 25    2012-10
# 15866     65   7.519521     15 to 25    2012-10
# 15867    173   7.519521     15 to 25    2012-10
# 15868    330   6.495439     15 to 25    2012-10
# 15869    434   4.573730      5 to 15    2012-10
# 15870    462   5.403502     15 to 25    2012-10
# 15871    491   6.675266      5 to 15    2012-10
# 15872    391   6.675266      5 to 15    2012-10
# 15873    402   7.519521     15 to 25    2012-10
# 15874    301   8.484193     15 to 25    2012-10
# 15875    293   8.539184      5 to 15    2012-10
# 15876    225   9.642537      5 to 15    2012-10
# 15877    154  10.765972      5 to 15    2012-10
# 15878     54  10.765972      5 to 15    2012-10
# 15879     55  10.765972      5 to 15    2012-10
# 15880     46  10.762605      5 to 15    2012-10
# 15881     37  10.762605      5 to 15    2012-10
# 15882     14  10.765972      5 to 15    2012-10

# %%
df_hourly[df_hourly['date'] == '2012-10-31']
# Out:
#             date  season  year  month  hour holiday day_of_week work_day  \
# 15895 2012-10-31  autumn  2012     10     0      no         wed      yes
# 15896 2012-10-31  autumn  2012     10     1      no         wed      yes
# 15897 2012-10-31  autumn  2012     10     2      no         wed      yes
# 15898 2012-10-31  autumn  2012     10     3      no         wed      yes
# 15899 2012-10-31  autumn  2012     10     4      no         wed      yes
# 15900 2012-10-31  autumn  2012     10     5      no         wed      yes
# 15901 2012-10-31  autumn  2012     10     6      no         wed      yes
# 15902 2012-10-31  autumn  2012     10     7      no         wed      yes
# 15903 2012-10-31  autumn  2012     10     8      no         wed      yes
# 15904 2012-10-31  autumn  2012     10     9      no         wed      yes
# 15905 2012-10-31  autumn  2012     10    10      no         wed      yes
# 15906 2012-10-31  autumn  2012     10    11      no         wed      yes
# 15907 2012-10-31  autumn  2012     10    12      no         wed      yes
# 15908 2012-10-31  autumn  2012     10    13      no         wed      yes
# 15909 2012-10-31  autumn  2012     10    14      no         wed      yes
# 15910 2012-10-31  autumn  2012     10    15      no         wed      yes
# 15911 2012-10-31  autumn  2012     10    16      no         wed      yes
# 15912 2012-10-31  autumn  2012     10    17      no         wed      yes
# 15913 2012-10-31  autumn  2012     10    18      no         wed      yes
# 15914 2012-10-31  autumn  2012     10    19      no         wed      yes
# 15915 2012-10-31  autumn  2012     10    20      no         wed      yes
# 15916 2012-10-31  autumn  2012     10    21      no         wed      yes
# 15917 2012-10-31  autumn  2012     10    22      no         wed      yes
# 15918 2012-10-31  autumn  2012     10    23      no         wed      yes
#
#       weather_sit  temp  app_temp  humidity  wind_speed  casual  registered  \
# 15895       misty   6.1       5.0      81.0         7.0       0          16
# 15896       misty   6.1       5.0      81.0         6.0       0           8
# 15897       misty   6.1       4.0      81.0         9.0       0           7
# 15898       misty   6.1       5.0      81.0         7.0       0           3
# 15899       misty   6.1       3.0      87.0        13.0       0           5
# 15900       misty   6.1       4.0      81.0         9.0       0          24
# 15901       clear   6.1       4.0      81.0        11.0       0         116
# 15902       misty   6.1       4.0      87.0         9.0       3         334
# 15903       clear   7.0       6.0      81.0         9.0       6         615
# 15904       clear   8.0       6.0      76.0         9.0      17         280
# 15905       clear   8.9       6.0      71.0        19.0      21         147
# 15906       misty   8.9       7.0      66.0        15.0      37         152
# 15907       clear  10.8      11.0      58.0        13.0      44         197
# 15908       clear  11.7      12.0      50.0        15.0      22         191
# 15909       misty  11.7      12.0      50.0        15.0      45         179
# 15910       clear  11.7      12.0      54.0        11.0      33         197
# 15911       misty  11.7      12.0      54.0        15.0      51         373
# 15912       misty  10.8      11.0      58.0        11.0      39         684
# 15913       misty  10.8      11.0      58.0        11.0      28         556
# 15914       misty  10.8      11.0      50.0        13.0      27         383
# 15915       misty  10.8      11.0      50.0        13.0       9         259
# 15916       misty  10.8      11.0      50.0        13.0      12         180
# 15917       clear   8.9       7.0      57.0         9.0      18         147
# 15918       clear   8.9       8.0      57.0         6.0       7          94
#
#        total  dew_point app_temp_cat year_month
# 15895     16   3.086630      -5 to 5    2012-10
# 15896      8   3.086630      -5 to 5    2012-10
# 15897      7   3.086630      -5 to 5    2012-10
# 15898      3   3.086630      -5 to 5    2012-10
# 15899      5   4.100131      -5 to 5    2012-10
# 15900     24   3.086630      -5 to 5    2012-10
# 15901    116   3.086630      -5 to 5    2012-10
# 15902    337   4.100131      -5 to 5    2012-10
# 15903    621   3.964480      5 to 15    2012-10
# 15904    297   4.029405      5 to 15    2012-10
# 15905    168   3.928718      5 to 15    2012-10
# 15906    189   2.894564      5 to 15    2012-10
# 15907    241   2.867309      5 to 15    2012-10
# 15908    213   1.621807      5 to 15    2012-10
# 15909    224   1.621807      5 to 15    2012-10
# 15910    230   2.700423      5 to 15    2012-10
# 15911    424   2.700423      5 to 15    2012-10
# 15912    723   2.867309      5 to 15    2012-10
# 15913    584   2.867309      5 to 15    2012-10
# 15914    410   0.792954      5 to 15    2012-10
# 15915    268   0.792954      5 to 15    2012-10
# 15916    192   0.792954      5 to 15    2012-10
# 15917    165   0.844919      5 to 15    2012-10
# 15918    101   0.844919      5 to 15    2012-10

# %% [markdown]
# Return to these missing values later. <br>
# For now, save dataframes as they are (with basic cleaning and wrangling).

# %%
df_daily.to_csv('cleaned_data/df_daily.csv')
df_hourly.to_csv('cleaned_data/df_hourly.csv')
