# %%
import pandas as pd
import geopandas as gpd
import geopandas.tools
from geopy.geocoders import Nominatim
import geopy
from geopandas.tools import geocode
from geopy.extra.rate_limiter import RateLimiter
from difflib import SequenceMatcher

import numpy as np

# %%
missing_stations = ['Crystal City Metro / 18th & Bell St',
 '21st & M St NW',
 'Eastern Market Metro / Pennsylvania Ave & 7th St SE',
 'Connecticut Ave & Newark St NW / Cleveland Park',
 '18th & Eads St.',
 '19th & L St NW',
 '23rd & Crystal Dr',
 'Aurora Hills Community Ctr/18th & Hayes St',
 'S Joyce & Army Navy Dr',
 'Georgia Ave and Fairmont St NW',
 '20th & Crystal Dr',
 'S Glebe & Potomac Ave',
 'USDA / 12th & Independence Ave SW',
 '27th & Crystal Dr',
 'Pentagon City Metro / 12th & S Hayes St',
 '12th & Army Navy Dr',
 '26th & S Clark St',
 '15th & Crystal Dr',
 'Eads & 22nd St S',
 '1st & N St  SE',
 'Lynn & 19th St North',
 'N Rhodes & 16th St N',
 'Rosslyn Metro / Wilson Blvd & Ft Myer Dr',
 'Wilson Blvd & Franklin Rd',
 '11th & H St NE']

# %%
missing_stations
# Out:
# ['Crystal City Metro / 18th & Bell St',
#  '21st & M St NW',
#  'Eastern Market Metro / Pennsylvania Ave & 7th St SE',
#  'Connecticut Ave & Newark St NW / Cleveland Park',
#  '18th & Eads St.',
#  '19th & L St NW',
#  '23rd & Crystal Dr',
#  'Aurora Hills Community Ctr/18th & Hayes St',
#  'S Joyce & Army Navy Dr',
#  'Georgia Ave and Fairmont St NW',
#  '20th & Crystal Dr',
#  'S Glebe & Potomac Ave',
#  'USDA / 12th & Independence Ave SW',
#  '27th & Crystal Dr',
#  'Pentagon City Metro / 12th & S Hayes St',
#  '12th & Army Navy Dr',
#  '26th & S Clark St',
#  '15th & Crystal Dr',
#  'Eads & 22nd St S',
#  '1st & N St  SE',
#  'Lynn & 19th St North',
#  'N Rhodes & 16th St N',
#  'Rosslyn Metro / Wilson Blvd & Ft Myer Dr',
#  'Wilson Blvd & Franklin Rd',
#  '11th & H St NE']

# %%
missing = pd.DataFrame(missing_stations)
missing = missing.rename(columns = {0: 'station'})

# %%
missing.head(10)
# Out:
#                                              station
# 0                Crystal City Metro / 18th & Bell St
# 1                                     21st & M St NW
# 2  Eastern Market Metro / Pennsylvania Ave & 7th ...
# 3    Connecticut Ave & Newark St NW / Cleveland Park
# 4                                    18th & Eads St.
# 5                                     19th & L St NW
# 6                                  23rd & Crystal Dr
# 7         Aurora Hills Community Ctr/18th & Hayes St
# 8                             S Joyce & Army Navy Dr
# 9                     Georgia Ave and Fairmont St NW

# %%
missing.head()
# Out:
#                                              station
# 0                Crystal City Metro / 18th & Bell St
# 1                                     21st & M St NW
# 2  Eastern Market Metro / Pennsylvania Ave & 7th ...
# 3    Connecticut Ave & Newark St NW / Cleveland Park
# 4                                    18th & Eads St.

# %%
station_loc = pd.read_csv('station_loc.csv')

# %%
station_loc.head()
# Out:
#    Unnamed: 0                                          name        lat  \
# 0           0                           Eads St & 15th St S  38.858971
# 1           1                        Crystal Dr & 20th St S  38.856425
# 2           2                        Crystal Dr & 15th St S  38.861056
# 3           3  Aurora Hills Cmty Ctr / 18th St & S Hayes St  38.857866
# 4           4    Pentagon City Metro / 12th St & S Hayes St  38.862303
#
#          lon  region_id         region
# 0 -77.053230         41  Arlington, VA
# 1 -77.049232         41  Arlington, VA
# 2 -77.049417         41  Arlington, VA
# 3 -77.059490         41  Arlington, VA
# 4 -77.059936         41  Arlington, VA

# %%
# If the address in "missing" is very close to the address in "station_loc", then use the region name from "station_loc"

for i in range(len(missing)):
    for j in range (len(station_loc)):
        if (SequenceMatcher(None, missing.loc[i,'station'], station_loc.loc[j, 'name'])).ratio()>= 0.9:
            #missing.loc[i,'alt_station'] = station_loc.loc[j,'name']
            missing.loc[i,'region'] = station_loc.loc[j,'region']

# %%
missing
# Out:
#                                               station          region
# 0                 Crystal City Metro / 18th & Bell St   Arlington, VA
# 1                                      21st & M St NW  Washington, DC
# 2   Eastern Market Metro / Pennsylvania Ave & 7th ...  Washington, DC
# 3     Connecticut Ave & Newark St NW / Cleveland Park             NaN
# 4                                     18th & Eads St.             NaN
# 5                                      19th & L St NW  Washington, DC
# 6                                   23rd & Crystal Dr             NaN
# 7          Aurora Hills Community Ctr/18th & Hayes St             NaN
# 8                              S Joyce & Army Navy Dr             NaN
# 9                      Georgia Ave and Fairmont St NW  Washington, DC
# 10                                  20th & Crystal Dr             NaN
# 11                              S Glebe & Potomac Ave   Arlington, VA
# 12                  USDA / 12th & Independence Ave SW             NaN
# 13                                  27th & Crystal Dr             NaN
# 14            Pentagon City Metro / 12th & S Hayes St   Arlington, VA
# 15                                12th & Army Navy Dr             NaN
# 16                                  26th & S Clark St             NaN
# 17                                  15th & Crystal Dr             NaN
# 18                                   Eads & 22nd St S   Arlington, VA
# 19                                     1st & N St  SE  Washington, DC
# 20                               Lynn & 19th St North   Arlington, VA
# 21                               N Rhodes & 16th St N             NaN
# 22           Rosslyn Metro / Wilson Blvd & Ft Myer Dr             NaN
# 23                          Wilson Blvd & Franklin Rd   Arlington, VA
# 24                                     11th & H St NE  Washington, DC

# %%
missing['region'] = missing['region'].fillna(0)

# %%
# Initialise 'lat' and 'lon' columns
missing['lat'] = np.zeros((len(missing),1))
missing['lon'] = np.zeros((len(missing),1))

# %%
geolocator = Nominatim(user_agent="bike_search")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
# Add a space at the beginning of the "region" entries + make sure format of "region" column is "string"
missing['region'] = " " + missing['region'].astype(str)

# %%
for i in range(len(missing)):

    try:
        if missing.loc[i, 'region'] == 0:           # If the "region" is missing, then do a bare geocode search
            dummy_lat = geocode(missing.loc[i,'station'], timeout = 15).latitude
            dummy_lon = geocode(missing.loc[i,'station'], timeout = 15).longitude

            if (dummy_lon > -78 and dummy_lon <-76) and (dummy_lat > 38.5 and dummy_lat<39.5):
                missing.loc[i, 'lat'] = dummy_lat
                missing.loc[i, 'lon'] = dummy_lon



        else:                                       # If "region" name is available, add it to the geocode search
            dummy_lat = geocode(missing.loc[i,'station'] + missing.loc[i, 'region'], timeout = 15).latitude
            dummy_lon = geocode(missing.loc[i,'station'] + missing.loc[i, 'region'], timeout = 15).longitude

            if (dummy_lon > -79 and dummy_lon <-76) and (dummy_lat > 38 and dummy_lat<40):
                missing.loc[i, 'lat'] = dummy_lat
                missing.loc[i, 'lon'] = dummy_lon



    except AttributeError:
        pass

# %%
missing
# Out:
#                                               station           region  \
# 0                 Crystal City Metro / 18th & Bell St    Arlington, VA
# 1                                      21st & M St NW   Washington, DC
# 2   Eastern Market Metro / Pennsylvania Ave & 7th ...   Washington, DC
# 3     Connecticut Ave & Newark St NW / Cleveland Park                0
# 4                                     18th & Eads St.                0
# 5                                      19th & L St NW   Washington, DC
# 6                                   23rd & Crystal Dr                0
# 7          Aurora Hills Community Ctr/18th & Hayes St                0
# 8                              S Joyce & Army Navy Dr                0
# 9                      Georgia Ave and Fairmont St NW   Washington, DC
# 10                                  20th & Crystal Dr                0
# 11                              S Glebe & Potomac Ave    Arlington, VA
# 12                  USDA / 12th & Independence Ave SW                0
# 13                                  27th & Crystal Dr                0
# 14            Pentagon City Metro / 12th & S Hayes St    Arlington, VA
# 15                                12th & Army Navy Dr                0
# 16                                  26th & S Clark St                0
# 17                                  15th & Crystal Dr                0
# 18                                   Eads & 22nd St S    Arlington, VA
# 19                                     1st & N St  SE   Washington, DC
# 20                               Lynn & 19th St North    Arlington, VA
# 21                               N Rhodes & 16th St N                0
# 22           Rosslyn Metro / Wilson Blvd & Ft Myer Dr                0
# 23                          Wilson Blvd & Franklin Rd    Arlington, VA
# 24                                     11th & H St NE   Washington, DC
#
#           lat        lon
# 0    0.000000   0.000000
# 1   38.905107 -77.057402
# 2   38.884056 -76.995262
# 3    0.000000   0.000000
# 4    0.000000   0.000000
# 5   38.903799 -77.053958
# 6   38.853166 -77.050493
# 7    0.000000   0.000000
# 8    0.000000   0.000000
# 9   38.924900 -77.022200
# 10  38.856400 -77.049200
# 11   0.000000   0.000000
# 12  38.887197 -77.028289
# 13  38.848466 -77.051514
# 14  38.862179 -77.059986
# 15   0.000000   0.000000
# 16  38.851434 -77.051714
# 17   0.000000   0.000000
# 18   0.000000   0.000000
# 19  38.875114 -76.968739
# 20   0.000000   0.000000
# 21   0.000000   0.000000
# 22  38.894600 -77.072305
# 23  38.890400 -77.088900
# 24  38.900164 -77.005441

# %%
string1 = 'abcde/fghi'
string1.split('/')[0], string1.split('/')[1]
# Out:
# ('abcde', 'fghi')

# %%
for i in range(len(missing)):

    try:
        if missing.loc[i, 'lat'] == 0 and missing.loc[i, 'region'] != 0:
            dummy_lat = geocode(missing.loc[i,'station'], timeout = 15).latitude
            dummy_lon = geocode(missing.loc[i,'station'], timeout = 15).longitude

            if (dummy_lon > -78 and dummy_lon <-76) and (dummy_lat > 38.5 and dummy_lat<39.5):
                missing.loc[i, 'lat'] = dummy_lat
                missing.loc[i, 'lon'] = dummy_lon
            
    

    except AttributeError:
        pass

# %%
missing
# Out:
#                                               station           region  \
# 0                 Crystal City Metro / 18th & Bell St    Arlington, VA
# 1                                      21st & M St NW   Washington, DC
# 2   Eastern Market Metro / Pennsylvania Ave & 7th ...   Washington, DC
# 3     Connecticut Ave & Newark St NW / Cleveland Park                0
# 4                                     18th & Eads St.                0
# 5                                      19th & L St NW   Washington, DC
# 6                                   23rd & Crystal Dr                0
# 7          Aurora Hills Community Ctr/18th & Hayes St                0
# 8                              S Joyce & Army Navy Dr                0
# 9                      Georgia Ave and Fairmont St NW   Washington, DC
# 10                                  20th & Crystal Dr                0
# 11                              S Glebe & Potomac Ave    Arlington, VA
# 12                  USDA / 12th & Independence Ave SW                0
# 13                                  27th & Crystal Dr                0
# 14            Pentagon City Metro / 12th & S Hayes St    Arlington, VA
# 15                                12th & Army Navy Dr                0
# 16                                  26th & S Clark St                0
# 17                                  15th & Crystal Dr                0
# 18                                   Eads & 22nd St S    Arlington, VA
# 19                                     1st & N St  SE   Washington, DC
# 20                               Lynn & 19th St North    Arlington, VA
# 21                               N Rhodes & 16th St N                0
# 22           Rosslyn Metro / Wilson Blvd & Ft Myer Dr                0
# 23                          Wilson Blvd & Franklin Rd    Arlington, VA
# 24                                     11th & H St NE   Washington, DC
#
#           lat        lon
# 0    0.000000   0.000000
# 1   38.905107 -77.057402
# 2   38.884056 -76.995262
# 3   38.934267 -77.057979
# 4    0.000000   0.000000
# 5   38.903799 -77.053958
# 6   38.853166 -77.050493
# 7   38.857874 -77.059492
# 8   38.865710 -77.061773
# 9   38.924900 -77.022200
# 10  38.856400 -77.049200
# 11  38.832561 -77.048147
# 12  38.887197 -77.028289
# 13  38.848466 -77.051514
# 14  38.862179 -77.059986
# 15  38.860653 -77.068508
# 16  38.851434 -77.051714
# 17   0.000000   0.000000
# 18  38.854389 -77.053414
# 19  38.875114 -76.968739
# 20  38.897315 -77.070993
# 21  38.892164 -77.079375
# 22  38.894600 -77.072305
# 23  38.890400 -77.088900
# 24  38.900164 -77.005441

# %%
for i in range(len(missing)):

    try:
        if "/" in missing.loc[i, 'station']:
            dummy_string = missing.loc[i, 'station'].split('/')[0]          # Check part that comes before separator '/'
            
            dummy_lat = geocode(dummy_string, timeout = 15).latitude
            dummy_lon = geocode(dummy_string, timeout = 15).longitude

            if (dummy_lon > -78 and dummy_lon <-76) and (dummy_lat > 38.5 and dummy_lat<39.5):
                missing.loc[i, 'lat'] = dummy_lat
                missing.loc[i, 'lon'] = dummy_lon
    

    except AttributeError:
        pass

# %%
missing
# Out:
#                                               station           region  \
# 0                 Crystal City Metro / 18th & Bell St    Arlington, VA
# 1                                      21st & M St NW   Washington, DC
# 2   Eastern Market Metro / Pennsylvania Ave & 7th ...   Washington, DC
# 3     Connecticut Ave & Newark St NW / Cleveland Park                0
# 4                                     18th & Eads St.                0
# 5                                      19th & L St NW   Washington, DC
# 6                                   23rd & Crystal Dr                0
# 7          Aurora Hills Community Ctr/18th & Hayes St                0
# 8                              S Joyce & Army Navy Dr                0
# 9                      Georgia Ave and Fairmont St NW   Washington, DC
# 10                                  20th & Crystal Dr                0
# 11                              S Glebe & Potomac Ave    Arlington, VA
# 12                  USDA / 12th & Independence Ave SW                0
# 13                                  27th & Crystal Dr                0
# 14            Pentagon City Metro / 12th & S Hayes St    Arlington, VA
# 15                                12th & Army Navy Dr                0
# 16                                  26th & S Clark St                0
# 17                                  15th & Crystal Dr                0
# 18                                   Eads & 22nd St S    Arlington, VA
# 19                                     1st & N St  SE   Washington, DC
# 20                               Lynn & 19th St North    Arlington, VA
# 21                               N Rhodes & 16th St N                0
# 22           Rosslyn Metro / Wilson Blvd & Ft Myer Dr                0
# 23                          Wilson Blvd & Franklin Rd    Arlington, VA
# 24                                     11th & H St NE   Washington, DC
#
#           lat        lon
# 0   38.857756 -77.051196
# 1   38.905107 -77.057402
# 2   38.884056 -76.995262
# 3   38.934267 -77.057979
# 4    0.000000   0.000000
# 5   38.903799 -77.053958
# 6   38.853166 -77.050493
# 7   38.857792 -77.059103
# 8   38.865710 -77.061773
# 9   38.924900 -77.022200
# 10  38.856400 -77.049200
# 11  38.832561 -77.048147
# 12  38.887841 -77.029994
# 13  38.848466 -77.051514
# 14  38.862660 -77.059205
# 15  38.860653 -77.068508
# 16  38.851434 -77.051714
# 17   0.000000   0.000000
# 18  38.854389 -77.053414
# 19  38.875114 -76.968739
# 20  38.897315 -77.070993
# 21  38.892164 -77.079375
# 22  38.891328 -77.085031
# 23  38.890400 -77.088900
# 24  38.900164 -77.005441

# %%
missing_2011 = missing.copy(deep = True)

# %%
missing_2011.to_csv('cleaned_data/missing_2011.csv', index = False)

# %%
geo = geocode(missing['station'], provider='nominatim', user_agent = "bike_search", timeout = 15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/Oh/Documents/CodeAcademyBerlin/bike_analysis/geopandas.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/Oh/Documents/CodeAcademyBerlin/bike_analysis/geopandas.ipynb#ch0000005?line=0'>1</a> geo = geocode(missing['station'], provider='nominatim', user_agent = "bike_search", timeout = 15)
#
# File /opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py:274, in RateLimiter.__call__(self, *args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py?line=271'>272</a> self._acquire_request_slot()
#     <a href='file:///opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py?line=272'>273</a> try:
# --> <a href='file:///opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py?line=273'>274</a>     res = self.func(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py?line=274'>275</a>     if inspect.isawaitable(res):
#     <a href='file:///opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py?line=275'>276</a>         raise ValueError(
#     <a href='file:///opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py?line=276'>277</a>             "An async awaitable has been passed to `RateLimiter`. "
#     <a href='file:///opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py?line=277'>278</a>             "Use `AsyncRateLimiter` instead, which supports awaitables."
#     <a href='file:///opt/anaconda3/envs/geo_pandas/lib/python3.8/site-packages/geopy/extra/rate_limiter.py?line=278'>279</a>         )
#
# TypeError: geocode() got an unexpected keyword argument 'provider'

# %%
geo
# Out:
#                       geometry  \
# 0     GEOMETRYCOLLECTION EMPTY
# 1   POINT (-77.05740 38.90511)
# 2   POINT (-76.99526 38.88406)
# 3   POINT (-77.05798 38.93427)
# 4   POINT (-90.05047 30.01950)
# 5   POINT (-77.05396 38.90380)
# 6   POINT (-77.04969 38.85303)
# 7   POINT (-77.05949 38.85787)
# 8   POINT (-77.06177 38.86571)
# 9   POINT (-77.02220 38.92490)
# 10  POINT (-81.83064 26.56502)
# 11  POINT (-77.04815 38.83256)
# 12  POINT (-77.02829 38.88720)
# 13  POINT (-81.83064 26.56502)
# 14    GEOMETRYCOLLECTION EMPTY
# 15  POINT (-77.06851 38.86065)
# 16  POINT (-77.05171 38.85143)
# 17  POINT (-81.83064 26.56502)
# 18  POINT (-77.05341 38.85439)
# 19  POINT (-79.03073 41.08613)
# 20  POINT (-77.07099 38.89731)
# 21  POINT (-77.07937 38.89216)
# 22  POINT (-77.07231 38.89460)
# 23  POINT (-77.08890 38.89040)
# 24  POINT (-94.17966 46.36713)
#
#                                               address
# 0                                                None
# 1   M St NW, Peter Square, Georgetown, Washington,...
# 2   Eastern Market Metro/Pennsylvania Ave & 7th St...
# 3   Connecticut Ave and Newark St NW / Cleveland P...
# 4   Eads Street, Lake Oaks, New Orleans, Orleans P...
# 5   L St NW, West End, Washington, District of Col...
# 6   23rd and Crystal Dr, South Crystal Drive, Nati...
# 7   Aurora Hills Community Ctr/18th and Hayes St, ...
# 8   Army Navy Dr at S Joyce St, Army Navy Drive, P...
# 9   Georgia Ave and Fairmont St NW, 2400, 6th Stre...
# 10  Crystal Dr, Lee County, Florida, 33966, United...
# 11  E Glebe Rd & Potomac Ave, East Glebe Road, Jef...
# 12  USDA / 12th and Independence Ave SW, Independe...
# 13  Crystal Dr, Lee County, Florida, 33966, United...
# 14                                               None
# 15  Army Navy Drive, Virginia Highlands, Arlington...
# 16  S Clark St & 26th St, South Clark Street, Nati...
# 17  Crystal Dr, Lee County, Florida, 33966, United...
# 18  Eads and 22nd St S, South Eads Street, Nationa...
# 19  1st North Street, Knox Dale, Knox Township, Je...
# 20  Lynn and 19th St North, North Lynn Street, Ros...
# 21  N Rhodes and 16th St N, North Rhodes Street, C...
# 22  Rosslyn Metro / Wilson Blvd and Ft Myer Dr, No...
# 23  Wilson Blvd and Franklin Rd, Wilson Boulevard,...
# 24  H Street Northeast, East Gate Mobile Home Park...
